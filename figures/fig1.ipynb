# %%
import sys
sys.path.append('../')
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib as mpl
from PIL import Image
import seaborn as sns
from sfp_nsdsyn import prep, stim, utils

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Figure 1a
# In order to plot the figure 1a, you need to have natural-scenes-dataset/nsddata/stimuli/nsdsynthetic/nsdsynthetic downloaded. The w_a and w_r information will be downloaded using `prep.load_stim_info_as_df()`

# %%
rc = {'text.color': 'black',
      'axes.labelcolor': 'black',
      'xtick.color': 'black',
      'ytick.color': 'black',
      'axes.edgecolor': 'black',
      'font.family': 'Helvetica',
      'axes.linewidth': 1,
      'axes.labelpad': 6,
      'xtick.major.pad': 10,
      'xtick.major.width': 1,
      'ytick.major.width': 1,
      'lines.linewidth': 1,
      'font.size': 12,
      'axes.titlesize': 12,
      'axes.titleweight': 'bold',
      'axes.labelsize': 12,
      'xtick.labelsize': 10,
      'ytick.labelsize': 10,
      'legend.title_fontsize': 11,
      'legend.fontsize': 11,
      'figure.titlesize': 11,
      'figure.dpi': 72 * 3,
      'savefig.dpi': 72 * 4
      }
mpl.rcParams.update(rc)

# %%
## remove this part when you run the notebook
import json
config = json.load(open('../config.json'))
##
## edit the paths below for your configurations
NSD_path = config['NSD_DIR']
nsd_stim_info_path = config['NSD_DIR']
broderick_stim_info_path = '/Volumes/server/Projects/sfp_nsd/Broderick_dataset/'

##
stim_info_df = pd.read_csv(os.path.join(nsd_stim_info_path, 'nsdsyn_stim_description.csv'))
bd_stim_info = pd.read_csv(os.path.join(broderick_stim_info_path, 'broderick_stim_description.csv'))

# %%
im_numbers = [105, 113, 129, 137, 153, 161, 177, 185]
img_to_draw = stim_info_df.query('image_idx in @im_numbers').sort_values('freq_lvl')
img_to_draw
# Out:
#     image_idx  stim_idx   w_r   w_a  phase  class_idx  phase_idx  \
# 0         105         0   0.0  -6.0    0.0          0          0
# 24        129        24   4.0  -4.0    0.0          6          0
# 48        153        48   6.0  -0.0    0.0         12          0
# 72        177        72   4.0   4.0    0.0         18          0
# 8         113         8   0.0 -20.0    0.0          2          0
# 32        137        32  14.0 -14.0    0.0          8          0
# 56        161        56  20.0  -0.0    0.0         14          0
# 80        185        80  14.0  14.0    0.0         20          0
#
#              names  freq_lvl
# 0         pinwheel         0
# 24  forward spiral         0
# 48         annulus         0
# 72  reverse spiral         0
# 8         pinwheel         2
# 32  forward spiral         2
# 56         annulus         2
# 80  reverse spiral         2

# %%
main_classes = ['annulus', 'forward spiral', 'pinwheel', 'reverse spiral','mixtures']
img_to_draw = stim_info_df.query('names in @main_classes & phase == 0').sort_values('freq_lvl')
img_to_draw = img_to_draw.query('freq_lvl in [0,3]')
img_to_draw = img_to_draw.query('class_idx not in [25,26]').reset_index(drop=True)
img_to_draw.loc[img_to_draw.index[4], 'freq_lvl'] = 0

# Make sure img_to_draw is ordered by main_classes order in the 'names' column
img_to_draw['names'] = pd.Categorical(img_to_draw['names'], categories=main_classes, ordered=True)
img_to_draw = img_to_draw.sort_values(['freq_lvl','names']).reset_index(drop=True)
img_to_draw
# Out:
#    image_idx  stim_idx   w_r   w_a  phase  class_idx  phase_idx  \
# 0        153        48   6.0  -0.0    0.0         12          0
# 1        129        24   4.0  -4.0    0.0          6          0
# 2        105         0   0.0  -6.0    0.0          0          0
# 3        177        72   4.0   4.0    0.0         18          0
# 4        213       108  14.0  34.0    0.0         27          0
# 5        165        60  37.0  -0.0    0.0         15          0
# 6        141        36  26.0 -26.0    0.0          9          0
# 7        117        12   0.0 -37.0    0.0          3          0
# 8        189        84  26.0  26.0    0.0         21          0
# 9        201        96  14.0 -34.0    0.0         24          0
#
#             names  freq_lvl
# 0         annulus         0
# 1  forward spiral         0
# 2        pinwheel         0
# 3  reverse spiral         0
# 4        mixtures         0
# 5         annulus         3
# 6  forward spiral         3
# 7        pinwheel         3
# 8  reverse spiral         3
# 9        mixtures         3

# %%
width, height = (1360, 714) #image size presented in the NSD synthetic experiment 
# Calculate the coordinates for the center crop because the scaled gratings were a square at the center of the screen
left = (width - 714) // 2
top = (height - 714) // 2
right = left + 714
bottom = top + 714

# %%
fig, axes = plt.subplots(2, 5, figsize=(5,2.47), dpi=300)
names = ['Annulus', 'Forward\nspiral', 'Pinwheel', 'Reverse\nspiral','Mixtures']

for idx, row in img_to_draw.iterrows():
    pic = os.path.join(
        config['NSD_DIR'],
        'nsddata/stimuli/nsdsynthetic/nsdsynthetic',
        f'nsdsynthetic{row.image_idx}.png'
    )
    img = Image.open(pic).convert('L')
    # Crop the image
    img_cropped = img.crop((left, top, right, bottom))
    # Assume axes is shaped appropriately to place this image;
    # here we flatten for simplicity. 
    if idx < 5:
        axes.flatten()[idx].set_title(f'{names[idx]}')
    axes.flatten()[idx].imshow(img_cropped, cmap=plt.get_cmap('gray'), vmin=0, vmax=255)
    axes.flatten()[idx].axis('off')

# Remove the image from axes[0, -1] and leave it empty
axes[0, -1].imshow([[1]], cmap=plt.get_cmap('gray'), vmin=0, vmax=1)
axes[0, -1].axis('off')
axes[0, -1].set_title('')
axes[1, -1].set_title('Mixtures')
fig.subplots_adjust(wspace=0.04, hspace=0.02)
utils.save_fig('/Volumes/server/Projects/sfp_nsd/derivatives/figures/stimuli/nsd_synthetic_stimuli_mixtures.svg')

# %% [markdown]
# # Figure 1b
# Figure 1b. This figure was created in Illustrator using `nsdsynthetic133.png` under
# `natural-scenes-dataset/nsddata/stimuli/nsdsynthetic/nsdsynthetic/`
# and one of the forward spiral images from Broderick et al., presented in their VSS poster
# (https://archive.org/details/broderick-2018-mapping-spatial).

# %% [markdown]
# # Figure 1c

# %%
stim_info = stim_info_df.drop_duplicates(subset=['class_idx'])
bd_stim_info = bd_stim_info.drop_duplicates(subset=['class_idx'])

# %%
rc.update({'axes.linewidth': 1.2,
           'xtick.major.width': 1.2,
           'ytick.major.width': 1.2,
           'axes.labelpad': 4,
           'axes.titlepad': 10})
           
sns.set_theme(style="ticks", context='notebook', rc=rc, font_scale=1)
fig, axes = plt.subplots(1,2, sharey=True)
fig.set_size_inches(5, 5.5)
colors = [sns.color_palette('tab10', 10)[:][k] for k in [0,2,1,3,4]]
colors.append('gray')
for i, cat in enumerate(['annulus', 'pinwheel', 'forward spiral', 'reverse spiral', 'mixtures']):

    axes[0].scatter(stim_info.query(f'names == "{cat}"')['w_r'], 
                    stim_info.query(f'names == "{cat}"')['w_a'], label=cat, s=20, 
                    color=colors[i], edgecolors='w', linewidths=0.5, zorder=100, clip_on=False)
    axes[1].scatter(bd_stim_info.query(f'names == "{cat}"')['w_r'], 
                    bd_stim_info.query(f'names == "{cat}"')['w_a'], label=cat, s=20, 
                    color=colors[i], edgecolors='w', linewidths=0.5, zorder=100, clip_on=False)

radius_list = [6,11,20,37,69,128]  # Radius of the ring


for ax in axes:
    for radi in radius_list:
        circle1 = plt.Circle((0, 0), radi, linewidth=1.2, color='grey', clip_on=True, fill=False)
        ax.add_patch(circle1)    
    ax.set(xlim=(0, 129), ylim=(-129, 129), yticks=[-128,-69,0,69,128], xticks=[0, 128])
    #ax.legend(bbox_to_anchor=(1.1, 0.9), frameon=False, title='Category')
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.set_aspect('equal')
    ax.set_xlabel(r"$\omega_r$")

fig.subplots_adjust(wspace=1)
axes[0].set_ylabel(r"$\omega_a$")
axes[1].set_ylabel('')
axes[0].set_title('NSD Synthetic')
axes[1].set_title('Broderick et al. (2022)')
axes[1].legend(bbox_to_anchor=(1.1, 1), frameon=False, title='Category')
